# %%
import numpy as np
import pandas as pd 
from scipy import stats
from pylab import *

df = pd.read_csv('datasets/pokemon.csv')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
pd.pivot_table(df, index='Name')
# Out:
#                            #  Attack  Defense  Generation   HP  Legendary  \
# Name
# Abomasnow                460      92       75           4   90      False
# AbomasnowMega Abomasnow  460     132      105           4   90      False
# Abra                      63      20       15           1   25      False
# Absol                    359     130       60           3   65      False
# AbsolMega Absol          359     150       60           3   65      False
# ...                      ...     ...      ...         ...  ...        ...
# Zoroark                  571     105       60           5   60      False
# Zorua                    570      65       40           5   40      False
# Zubat                     41      45       35           1   40      False
# Zweilous                 634      85       70           5   72      False
# Zygarde50% Forme         718     100      121           6  108       True
#
#                          Sp. Atk  Sp. Def  Speed  Total
# Name
# Abomasnow                     92       85     60    494
# AbomasnowMega Abomasnow      132      105     30    594
# Abra                         105       55     90    310
# Absol                         75       60     75    465
# AbsolMega Absol              115       60    115    565
# ...                          ...      ...    ...    ...
# Zoroark                      120       60    105    510
# Zorua                         80       40     65    330
# Zubat                         30       40     55    245
# Zweilous                      65       70     58    420
# Zygarde50% Forme              81       95     95    600
#
# [800 rows x 10 columns]

# %%
pd.pivot_table(df, index='Name', values=('Attack', 'Sp. Def'))
# Out:
#                          Attack  Sp. Def
# Name
# Abomasnow                    92       85
# AbomasnowMega Abomasnow     132      105
# Abra                         20       55
# Absol                       130       60
# AbsolMega Absol             150       60
# ...                         ...      ...
# Zoroark                     105       60
# Zorua                        65       40
# Zubat                        45       40
# Zweilous                     85       70
# Zygarde50% Forme            100       95
#
# [800 rows x 2 columns]

# %%
pd.pivot_table(df, index='Name', values=('Attack', 'Sp. Def'), aggfunc='sum', margins=True)
# Out:
#                          Attack  Sp. Def
# Name
# Abomasnow                    92       85
# AbomasnowMega Abomasnow     132      105
# Abra                         20       55
# Absol                       130       60
# AbsolMega Absol             150       60
# ...                         ...      ...
# Zorua                        65       40
# Zubat                        45       40
# Zweilous                     85       70
# Zygarde50% Forme            100       95
# All                       63201    57522
#
# [801 rows x 2 columns]

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.countplot(x='Type 1', 
              data =df)
plt.xticks (rotation = 45)
plt.yticks (rotation = 45)
plt.show()

# %%
sns.distplot(df['Total'])
plt.show()
